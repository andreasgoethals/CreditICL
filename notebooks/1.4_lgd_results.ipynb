# %% [markdown]
# # 1.4 · LGD results
#
# How the trained arms score on the real LGD datasets — the phase-2 benchmark. Reads output/results/lgd/eval/; safe to run before the benchmark exists (it shows placeholders until then).

# %%
# %load_ext autoreload
# %autoreload 2

import sys, pathlib
ROOT = pathlib.Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import numpy as np
import pandas as pd
from src.visualize import results_plots, figures, style

style.apply()
pd.set_option("display.width", 200, "display.max_columns", 40)

TASK = "lgd"
# Reads the phase-2 benchmark output from output/results/<task>/eval/. Until the benchmark has
# run (it needs every arm trained), each figure shows a "not scored yet" panel rather than error.
FIGS = figures.FigureSaver("1.4_lgd_results")

# %% [markdown]
# ## 1. Overall ranking

# %%
FIGS.save(results_plots.overall_ranking(TASK), "overall_ranking",
    caption="Mean real-data R² per model across the evaluation datasets and seeds, sorted; bars coloured by kind (credit prior, control, external baseline) with standard-deviation whiskers.");

# %% [markdown]
# ## 2. Per-dataset breakdown

# %%
FIGS.save(results_plots.per_dataset(TASK), "per_dataset",
    caption="Best real-data R² per model kind (credit prior, control, baseline), grouped bars, one group per evaluation dataset.");

# %% [markdown]
# ## 3. Credit prior vs control

# %%
FIGS.save(results_plots.credit_vs_control(TASK), "credit_vs_control",
    caption="Per-model real-data R² per model, one column per kind (credit prior, control, baseline); each point is a model and the bar is the group mean.");

# %% [markdown]
# ## Summary

# %%
print(results_plots.results_summary(TASK))
print()
print(FIGS.summary())
